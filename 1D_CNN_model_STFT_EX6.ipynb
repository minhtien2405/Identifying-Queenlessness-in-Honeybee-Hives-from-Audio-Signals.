# %%
import os
import time
import librosa
import librosa.display
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd 
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import *

import tensorflow as tf
from tensorflow.keras import *
from tensorflow.keras.callbacks import *

import warnings
warnings.filterwarnings('ignore')

# %%
path = os.getcwd() + "/dataset/"
path
# Out:
# '/root/dataset/'

# %%
TRAINING_DIR = path+"/train"
VALIDATION_DIR = path + "/val"
TEST_DIR = path + "/test"

print(TRAINING_DIR)
print(VALIDATION_DIR)
print(TEST_DIR)
# Out:
# /root/dataset//train
# /root/dataset//val
# /root/dataset//test

# %%
def data_loader(path):
    X = []
    Y = []
    for folder in os.listdir(path):
        for file in os.listdir(os.path.join(path, folder)):
            feature = np.load(os.path.join(path, folder, file))
            label = folder
            X.append(feature)
            Y.append(label)
    return X, Y

# %%
X_train, Y_train = data_loader(TRAINING_DIR)
X_val, Y_val = data_loader(VALIDATION_DIR)
X_test, Y_test = data_loader(TEST_DIR)

# %%
print("There are {} training samples and {} training labels".format(len(X_train), len(Y_train)))
print("There are {} validation samples and {} validation labels".format(len(X_val), len(Y_val)))
print("There are {} testing samples and {} testing labels".format(len(X_test), len(Y_test)))
# Out:
# There are 14000 training samples and 14000 training labels
# There are 2000 validation samples and 2000 validation labels
# There are 4000 testing samples and 4000 testing labels

# %%
X_train = np.array(X_train)
X_val = np.array(X_val)
X_test = np.array(X_test)
Y_train = np.array(Y_train)
Y_val = np.array(Y_val)
Y_test = np.array(Y_test)

print("Shape of X_train: {}".format(X_train.shape))
print("Shape of X_val: {}".format(X_val.shape))
print("Shape of X_test: {}".format(X_test.shape))
# Out:
# Shape of X_train: (14000, 64575)
# Shape of X_val: (2000, 64575)
# Shape of X_test: (4000, 64575)

# %%
# Reshape the input data
X_train = X_train.reshape( (X_train.shape[0], X_train.shape[1], 1) )
X_val = X_val.reshape( (X_val.shape[0], X_val.shape[1], 1) )
X_test = X_test.reshape( (X_test.shape[0], X_test.shape[1], 1) )
Y_train = Y_train.reshape( (Y_train.shape[0], 1) )
Y_val = Y_val.reshape( (Y_val.shape[0], 1) )
Y_test = Y_test.reshape( (Y_test.shape[0], 1) )

print("Shape of X_train: {}".format(X_train.shape))
print("Shape of X_val: {}".format(X_val.shape))
print("Shape of X_test: {}".format(X_test.shape))
# Out:
# Shape of X_train: (14000, 64575, 1)
# Shape of X_val: (2000, 64575, 1)
# Shape of X_test: (4000, 64575, 1)

# %%
# shuffle the dataset
shuffle_index = np.random.permutation(len(X_train))
X_train, Y_train = X_train[shuffle_index], Y_train[shuffle_index]
shuffle_index = np.random.permutation(len(X_val))
X_val, Y_val = X_val[shuffle_index], Y_val[shuffle_index]
shuffle_index = np.random.permutation(len(X_test))
X_test, Y_test = X_test[shuffle_index], Y_test[shuffle_index]

# %%
label_encoder = LabelEncoder()
Y_train = label_encoder.fit_transform(Y_train)
Y_val = label_encoder.fit_transform(Y_val)
Y_test = label_encoder.fit_transform(Y_test)

# %%
model = Sequential([
    layers.Input(shape=(X_train.shape[1:])),
    layers.Conv1D(16, 3, activation='relu'),
    layers.MaxPooling1D(2),
    layers.Conv1D(32, 3, activation='relu'),
    layers.MaxPooling1D(2),
    layers.Conv1D(64, 3, activation='relu'),
    layers.MaxPooling1D(2),
    layers.Conv1D(128, 3, activation='relu'),
    layers.MaxPooling1D(2),
    layers.Conv1D(256, 3, activation='relu'),
    layers.MaxPooling1D(2),
    layers.Conv1D(512, 3, activation='relu'),
    layers.MaxPooling1D(2),
    layers.Flatten(),
    layers.Dense(1024, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(512, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(1, activation='sigmoid')
])
# Out:
# 2023-06-27 11:17:38.212882: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-27 11:17:38.230295: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-27 11:17:38.230500: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-27 11:17:38.231736: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-27 11:17:38.231930: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-27 11:17:38.232082: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-27 11:17:38.903896: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-27 11:17:38.904127: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-27 11:17:38.904294: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-27 11:17:38.904429: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22250 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
              loss='binary_crossentropy',
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 64573, 16)         64
#
#  max_pooling1d (MaxPooling1D  (None, 32286, 16)        0
#  )
#
#  conv1d_1 (Conv1D)           (None, 32284, 32)         1568
#
#  max_pooling1d_1 (MaxPooling  (None, 16142, 32)        0
#  1D)
#
#  conv1d_2 (Conv1D)           (None, 16140, 64)         6208
#
#  max_pooling1d_2 (MaxPooling  (None, 8070, 64)         0
#  1D)
#
#  conv1d_3 (Conv1D)           (None, 8068, 128)         24704
#
#  max_pooling1d_3 (MaxPooling  (None, 4034, 128)        0
#  1D)
#
#  conv1d_4 (Conv1D)           (None, 4032, 256)         98560
#
#  max_pooling1d_4 (MaxPooling  (None, 2016, 256)        0
#  1D)
#
#  conv1d_5 (Conv1D)           (None, 2014, 512)         393728
#
#  max_pooling1d_5 (MaxPooling  (None, 1007, 512)        0
#  1D)
#
#  flatten (Flatten)           (None, 515584)            0
#
#  dense (Dense)               (None, 1024)              527959040
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 529,009,185
# Trainable params: 529,009,185
# Non-trainable params: 0
# _________________________________________________________________

# %%
earlystopper = EarlyStopping(
    monitor='val_loss',
    patience=20,
    restore_best_weights=True
)

# %%
epochs = 120
batch_size = 128
current_time = int(time.time())
stop_training_callback = earlystopper
history = model.fit(X_train, Y_train, 
                    epochs=epochs, 
                    batch_size=batch_size,
                    validation_data=(X_val, Y_val), 
                    callbacks=[stop_training_callback])
print("Training completed in {} seconds.".format(int(time.time()-current_time)))
# Out:
# Epoch 1/120
# 2023-06-27 11:17:45.060275: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8600
# 2023-06-27 11:17:47.419281: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:637] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-06-27 11:17:48.162307: I tensorflow/compiler/xla/service/service.cc:169] XLA service 0x7f0611b1f310 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-06-27 11:17:48.162341: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (0): NVIDIA GeForce RTX 3090, Compute Capability 8.6
# 2023-06-27 11:17:48.180362: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-06-27 11:17:48.406433: I ./tensorflow/compiler/jit/device_compiler.h:180] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 110/110 [==============================] - 45s 294ms/step - loss: 0.5501 - accuracy: 0.7025 - val_loss: 0.4791 - val_accuracy: 0.7910
# Epoch 2/120
# 110/110 [==============================] - 25s 224ms/step - loss: 0.4278 - accuracy: 0.8041 - val_loss: 0.3858 - val_accuracy: 0.8145
# Epoch 3/120
# 110/110 [==============================] - 25s 228ms/step - loss: 0.3675 - accuracy: 0.8304 - val_loss: 0.3260 - val_accuracy: 0.8490
# Epoch 4/120
# 110/110 [==============================] - 25s 223ms/step - loss: 0.3303 - accuracy: 0.8486 - val_loss: 0.2988 - val_accuracy: 0.8610
# Epoch 5/120
# 110/110 [==============================] - 25s 225ms/step - loss: 0.2910 - accuracy: 0.8665 - val_loss: 0.2677 - val_accuracy: 0.8845
# Epoch 6/120
# 110/110 [==============================] - 24s 223ms/step - loss: 0.2511 - accuracy: 0.8909 - val_loss: 0.2595 - val_accuracy: 0.8905
# Epoch 7/120
# 110/110 [==============================] - 25s 224ms/step - loss: 0.2261 - accuracy: 0.9022 - val_loss: 0.2250 - val_accuracy: 0.9130
# Epoch 8/120
# 110/110 [==============================] - 23s 213ms/step - loss: 0.2050 - accuracy: 0.9132 - val_loss: 0.2292 - val_accuracy: 0.9120
# Epoch 9/120
# 110/110 [==============================] - 25s 223ms/step - loss: 0.1939 - accuracy: 0.9205 - val_loss: 0.1938 - val_accuracy: 0.9205
# Epoch 10/120
# 110/110 [==============================] - 24s 222ms/step - loss: 0.1806 - accuracy: 0.9255 - val_loss: 0.1899 - val_accuracy: 0.9240
# Epoch 11/120
# 110/110 [==============================] - 24s 222ms/step - loss: 0.1600 - accuracy: 0.9354 - val_loss: 0.1706 - val_accuracy: 0.9280
# Epoch 12/120
# 110/110 [==============================] - 24s 221ms/step - loss: 0.1496 - accuracy: 0.9398 - val_loss: 0.1641 - val_accuracy: 0.9305
# Epoch 13/120
# 110/110 [==============================] - 24s 221ms/step - loss: 0.1421 - accuracy: 0.9419 - val_loss: 0.1544 - val_accuracy: 0.9395
# Epoch 14/120
# 110/110 [==============================] - 23s 212ms/step - loss: 0.1240 - accuracy: 0.9478 - val_loss: 0.1582 - val_accuracy: 0.9405
# Epoch 15/120
# 110/110 [==============================] - 24s 222ms/step - loss: 0.1191 - accuracy: 0.9511 - val_loss: 0.1330 - val_accuracy: 0.9505
# Epoch 16/120
# 110/110 [==============================] - 23s 212ms/step - loss: 0.1222 - accuracy: 0.9518 - val_loss: 0.1573 - val_accuracy: 0.9450
# Epoch 17/120
# 110/110 [==============================] - 23s 212ms/step - loss: 0.1080 - accuracy: 0.9575 - val_loss: 0.1562 - val_accuracy: 0.9460
# Epoch 18/120
# 110/110 [==============================] - 23s 213ms/step - loss: 0.1075 - accuracy: 0.9603 - val_loss: 0.1362 - val_accuracy: 0.9505
# Epoch 19/120
# 110/110 [==============================] - 23s 213ms/step - loss: 0.1050 - accuracy: 0.9591 - val_loss: 0.1371 - val_accuracy: 0.9465
# Epoch 20/120
# 110/110 [==============================] - 23s 214ms/step - loss: 0.0858 - accuracy: 0.9656 - val_loss: 0.1446 - val_accuracy: 0.9520
# Epoch 21/120
# 110/110 [==============================] - 23s 214ms/step - loss: 0.0851 - accuracy: 0.9659 - val_loss: 0.1370 - val_accuracy: 0.9545
# Epoch 22/120
# 110/110 [==============================] - 25s 228ms/step - loss: 0.0790 - accuracy: 0.9680 - val_loss: 0.1569 - val_accuracy: 0.9565
# Epoch 23/120
# 110/110 [==============================] - 27s 248ms/step - loss: 0.0768 - accuracy: 0.9689 - val_loss: 0.1355 - val_accuracy: 0.9575
# Epoch 24/120
# 110/110 [==============================] - 24s 220ms/step - loss: 0.0747 - accuracy: 0.9704 - val_loss: 0.1393 - val_accuracy: 0.9510
# Epoch 25/120
# 110/110 [==============================] - 24s 217ms/step - loss: 0.0768 - accuracy: 0.9696 - val_loss: 0.1404 - val_accuracy: 0.9545
# Epoch 26/120
# 110/110 [==============================] - 24s 217ms/step - loss: 0.0650 - accuracy: 0.9751 - val_loss: 0.1630 - val_accuracy: 0.9560
# Epoch 27/120
# 110/110 [==============================] - 24s 217ms/step - loss: 0.0648 - accuracy: 0.9759 - val_loss: 0.1369 - val_accuracy: 0.9535
# Epoch 28/120
# 110/110 [==============================] - 25s 224ms/step - loss: 0.0544 - accuracy: 0.9793 - val_loss: 0.1147 - val_accuracy: 0.9635
# Epoch 29/120
# 110/110 [==============================] - 23s 211ms/step - loss: 0.0558 - accuracy: 0.9798 - val_loss: 0.1805 - val_accuracy: 0.9560
# Epoch 30/120
# 110/110 [==============================] - 23s 211ms/step - loss: 0.0581 - accuracy: 0.9787 - val_loss: 0.1347 - val_accuracy: 0.9600
# Epoch 31/120
# 110/110 [==============================] - 23s 211ms/step - loss: 0.0514 - accuracy: 0.9808 - val_loss: 0.1877 - val_accuracy: 0.9580
# Epoch 32/120
# 110/110 [==============================] - 23s 211ms/step - loss: 0.0475 - accuracy: 0.9819 - val_loss: 0.1570 - val_accuracy: 0.9600
# Epoch 33/120
# 110/110 [==============================] - 23s 210ms/step - loss: 0.0500 - accuracy: 0.9818 - val_loss: 0.1583 - val_accuracy: 0.9505
# Epoch 34/120
# 110/110 [==============================] - 23s 211ms/step - loss: 0.0476 - accuracy: 0.9819 - val_loss: 0.1490 - val_accuracy: 0.9605
# Epoch 35/120
# 110/110 [==============================] - 23s 211ms/step - loss: 0.0396 - accuracy: 0.9857 - val_loss: 0.1413 - val_accuracy: 0.9585
# Epoch 36/120
# 110/110 [==============================] - 23s 211ms/step - loss: 0.0491 - accuracy: 0.9820 - val_loss: 0.1556 - val_accuracy: 0.9540
# Epoch 37/120
# 110/110 [==============================] - 23s 211ms/step - loss: 0.0443 - accuracy: 0.9834 - val_loss: 0.1420 - val_accuracy: 0.9555
# Epoch 38/120
# 110/110 [==============================] - 23s 211ms/step - loss: 0.0395 - accuracy: 0.9862 - val_loss: 0.1379 - val_accuracy: 0.9590
# Epoch 39/120
# 110/110 [==============================] - 23s 211ms/step - loss: 0.0376 - accuracy: 0.9850 - val_loss: 0.1397 - val_accuracy: 0.9590
# Epoch 40/120
# 110/110 [==============================] - 23s 211ms/step - loss: 0.0342 - accuracy: 0.9878 - val_loss: 0.1282 - val_accuracy: 0.9635
# Epoch 41/120
# 110/110 [==============================] - 23s 211ms/step - loss: 0.0310 - accuracy: 0.9886 - val_loss: 0.1448 - val_accuracy: 0.9625
# Epoch 42/120
# 110/110 [==============================] - 23s 211ms/step - loss: 0.0313 - accuracy: 0.9877 - val_loss: 0.1465 - val_accuracy: 0.9630
# Epoch 43/120
# 110/110 [==============================] - 23s 211ms/step - loss: 0.0285 - accuracy: 0.9895 - val_loss: 0.1581 - val_accuracy: 0.9580
# Epoch 44/120
# 110/110 [==============================] - 23s 211ms/step - loss: 0.0380 - accuracy: 0.9855 - val_loss: 0.1548 - val_accuracy: 0.9605
# Epoch 45/120
# 110/110 [==============================] - 23s 211ms/step - loss: 0.0256 - accuracy: 0.9907 - val_loss: 0.1844 - val_accuracy: 0.9560
# Epoch 46/120
# 110/110 [==============================] - 23s 211ms/step - loss: 0.0370 - accuracy: 0.9874 - val_loss: 0.1796 - val_accuracy: 0.9580
# Epoch 47/120
# 110/110 [==============================] - 23s 211ms/step - loss: 0.0320 - accuracy: 0.9896 - val_loss: 0.1977 - val_accuracy: 0.9575
# Epoch 48/120
# 110/110 [==============================] - 24s 215ms/step - loss: 0.0391 - accuracy: 0.9886 - val_loss: 0.1802 - val_accuracy: 0.9620
# Training completed in 1166 seconds.

# %%
plt.plot(epochs, loss, 'r', "Training Loss")
plt.plot(epochs, val_loss, 'b', "Validation Loss")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[34], line 3
#       1 plt.plot(epochs, loss, 'r', "Training Loss")
#       2 plt.plot(epochs, val_loss, 'b', "Validation Loss")
# ----> 3 plt.show()
#
# File /usr/local/lib/python3.8/dist-packages/matplotlib/pyplot.py:446, in show(*args, **kwargs)
#     402 """
#     403 Display all open figures.
#     404
#    (...)
#     443 explicitly there.
#     444 """
#     445 _warn_if_gui_out_of_main_thread()
# --> 446 return _get_backend_mod().show(*args, **kwargs)
#
# File /usr/local/lib/python3.8/dist-packages/matplotlib_inline/backend_inline.py:99, in show(close, block)
#      96 # only call close('all') if any to close
#      97 # close triggers gc.collect, which can be slow
#      98 if close and Gcf.get_all_fig_managers():
# ---> 99     matplotlib.pyplot.close('all')
#
# File /usr/local/lib/python3.8/dist-packages/matplotlib/_api/__init__.py:226, in caching_module_getattr.<locals>.__getattr__(name)
#     224 if name in props:
#     225     return props[name].__get__(instance)
# --> 226 raise AttributeError(
#     227     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'pyplot'

# %%
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
loss=history.history['loss']
val_loss=history.history['val_loss']

epochs=range(len(acc))

plt.plot(epochs, acc, 'r', "Training Accuracy")
plt.plot(epochs, val_acc, 'b', "Validation Accuracy")
plt.title('Training and validation accuracy')
plt.show()
print("")

plt.plot(epochs, loss, 'r', "Training Loss")
plt.plot(epochs, val_loss, 'b', "Validation Loss")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[32], line 11
#       9 plt.plot(epochs, val_acc, 'b', "Validation Accuracy")
#      10 plt.title('Training and validation accuracy')
# ---> 11 plt.show()
#      12 print("")
#      14 plt.plot(epochs, loss, 'r', "Training Loss")
#
# File /usr/local/lib/python3.8/dist-packages/matplotlib/pyplot.py:446, in show(*args, **kwargs)
#     402 """
#     403 Display all open figures.
#     404
#    (...)
#     443 explicitly there.
#     444 """
#     445 _warn_if_gui_out_of_main_thread()
# --> 446 return _get_backend_mod().show(*args, **kwargs)
#
# File /usr/local/lib/python3.8/dist-packages/matplotlib_inline/backend_inline.py:99, in show(close, block)
#      96 # only call close('all') if any to close
#      97 # close triggers gc.collect, which can be slow
#      98 if close and Gcf.get_all_fig_managers():
# ---> 99     matplotlib.pyplot.close('all')
#
# File /usr/local/lib/python3.8/dist-packages/matplotlib/_api/__init__.py:226, in caching_module_getattr.<locals>.__getattr__(name)
#     224 if name in props:
#     225     return props[name].__get__(instance)
# --> 226 raise AttributeError(
#     227     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'pyplot'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File /usr/local/lib/python3.8/dist-packages/matplotlib_inline/backend_inline.py:99, in show(close, block)
#      96 # only call close('all') if any to close
#      97 # close triggers gc.collect, which can be slow
#      98 if close and Gcf.get_all_fig_managers():
# ---> 99     matplotlib.pyplot.close('all')
#
# File /usr/local/lib/python3.8/dist-packages/matplotlib/_api/__init__.py:226, in caching_module_getattr.<locals>.__getattr__(name)
#     224 if name in props:
#     225     return props[name].__get__(instance)
# --> 226 raise AttributeError(
#     227     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'pyplot'

# %%
test_predict = model.predict(X_test)
# Out:
# 125/125 [==============================] - 2s 15ms/step

# %%
show_test_predict = np.round(test_predict, 0)
show_test_predict = pd.DataFrame(show_test_predict)
print(show_test_predict)
print(len(show_test_predict))
# Out:
#         0
# 0     1.0
# 1     0.0
# 2     0.0
# 3     1.0
# 4     1.0
# ...   ...
# 3995  0.0
# 3996  0.0
# 3997  0.0
# 3998  1.0
# 3999  0.0
#
# [4000 rows x 1 columns]
# 4000

# %%
from sklearn.metrics import roc_curve, auc
fpr, tpr, thresholds = roc_curve(Y_test, test_predict)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)'% roc_auc)
plt.plot([0,1],[0,1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0,1.0])
plt.ylim([0.0,1.05])
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend(loc="lower right")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[33], line 14
#      12 plt.title("ROC Curve")
#      13 plt.legend(loc="lower right")
# ---> 14 plt.show()
#
# File /usr/local/lib/python3.8/dist-packages/matplotlib/pyplot.py:446, in show(*args, **kwargs)
#     402 """
#     403 Display all open figures.
#     404
#    (...)
#     443 explicitly there.
#     444 """
#     445 _warn_if_gui_out_of_main_thread()
# --> 446 return _get_backend_mod().show(*args, **kwargs)
#
# File /usr/local/lib/python3.8/dist-packages/matplotlib_inline/backend_inline.py:99, in show(close, block)
#      96 # only call close('all') if any to close
#      97 # close triggers gc.collect, which can be slow
#      98 if close and Gcf.get_all_fig_managers():
# ---> 99     matplotlib.pyplot.close('all')
#
# File /usr/local/lib/python3.8/dist-packages/matplotlib/_api/__init__.py:226, in caching_module_getattr.<locals>.__getattr__(name)
#     224 if name in props:
#     225     return props[name].__get__(instance)
# --> 226 raise AttributeError(
#     227     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'pyplot'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File /usr/local/lib/python3.8/dist-packages/matplotlib_inline/backend_inline.py:99, in show(close, block)
#      96 # only call close('all') if any to close
#      97 # close triggers gc.collect, which can be slow
#      98 if close and Gcf.get_all_fig_managers():
# ---> 99     matplotlib.pyplot.close('all')
#
# File /usr/local/lib/python3.8/dist-packages/matplotlib/_api/__init__.py:226, in caching_module_getattr.<locals>.__getattr__(name)
#     224 if name in props:
#     225     return props[name].__get__(instance)
# --> 226 raise AttributeError(
#     227     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'pyplot'

# %%
from sklearn.metrics import f1_score
f1_score(Y_test, show_test_predict, average='macro')
# Out:
# 0.9622487518493581

# %%
from sklearn.metrics import confusion_matrix
cf = confusion_matrix(Y_test, show_test_predict)
display(cf)
# Out:
# array([[1936,   64],
#        [  87, 1913]])

# %%
stt = model.evaluate(X_test, Y_test)
print(stt)
# Out:
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1316 - accuracy: 0.9622
# [0.1315784454345703, 0.9622499942779541]

# %%
print(classification_report(Y_test, show_test_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.96      2000
#            1       0.97      0.96      0.96      2000
#
#     accuracy                           0.96      4000
#    macro avg       0.96      0.96      0.96      4000
# weighted avg       0.96      0.96      0.96      4000
